# %%
import pandas as pd
import re
import duckdb
from IPython.core.magic import register_cell_magic
from IPython.display import display, HTML

# %%
coreutils_function_types_data = {
    "function_name": list(),
    "argument_types": list(),
    "return_type": list()
}
pattern = r"(.*),args:\[(.*)\],ret:(.*)"

with open('data/coreutils_function_types.csv', 'r') as file:
    for line in file:
        match = re.search(pattern, line)
        function_name = match.group(1)
        argument_types = match.group(2).split(";")[:-1]
        return_type = match.group(3)
        coreutils_function_types_data["function_name"].append(function_name)
        coreutils_function_types_data["argument_types"].append(argument_types)
        coreutils_function_types_data["return_type"].append(return_type)
coreutils_df = pd.DataFrame(coreutils_function_types_data)
coreutils_argument_types_df = coreutils_df.explode("argument_types")

# %%
db = duckdb.connect(database=':memory:')
db.register('CoreUtilsFunctions', coreutils_df)
db.register('CoreUtilsArgumentTypes', coreutils_argument_types_df)

# %%
def db_query(line, cell):
    query = line + '\n' + cell
    df = db.execute(query).fetchdf()
    display(HTML(df.to_html()))

get_ipython().register_magic_function(db_query, 'cell')

# %%
# %%db_query
# SELECT *
# FROM CoreUtilsFunctions
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>function_name</th>
#       <th>argument_types</th>
#       <th>return_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>asnprintf</td>
#       <td>[i8*, i64*, i8*]</td>
#       <td>i8*</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>rpl_asprintf</td>
#       <td>[i8**, i8*]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>rpl_fopen</td>
#       <td>[i8*, i8*]</td>
#       <td>%struct._IO_FILE*</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>memcpy.inline</td>
#       <td>[i8*, i8*, i64]</td>
#       <td>i8*</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>orig_fopen</td>
#       <td>[i8*, i8*]</td>
#       <td>%struct._IO_FILE*</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>mktime_internal</td>
#       <td>[%struct.tm*, %struct.tm* (i64*, %struct.tm*)*, i64*]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>leapyear</td>
#       <td>[i64]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>ydhms_diff</td>
#       <td>[i64, i64, i32, i32, i32, i32, i32, i32, i32, i32]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>ranged_convert</td>
#       <td>[%struct.tm* (i64*, %struct.tm*)*, i64*, %struct.tm*]</td>
#       <td>%struct.tm*</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>tm_diff</td>
#       <td>[i64, i64, i32, i32, i32, %struct.tm*]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>isdst_differ</td>
#       <td>[i32, i32]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>convert_time</td>
#       <td>[%struct.tm* (i64*, %struct.tm*)*, i64, %struct.tm*]</td>
#       <td>%struct.tm*</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>rpl_mktime</td>
#       <td>[%struct.tm*]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>my_tzset</td>
#       <td>[]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>shr</td>
#       <td>[i64, i32]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>long_int_avg</td>
#       <td>[i64, i64]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>printf_fetchargs</td>
#       <td>[%"struct.std::__va_list"*, %struct.arguments*]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>printf_parse</td>
#       <td>[i8*, %struct.char_directives*, %struct.arguments*]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>xsum</td>
#       <td>[i64, i64]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>memcpy.inline</td>
#       <td>[i8*, i8*, i64]</td>
#       <td>i8*</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>vasnprintf</td>
#       <td>[i8*, i64*, i8*, %"struct.std::__va_list"*]</td>
#       <td>i8*</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>xsum4</td>
#       <td>[i64, i64, i64, i64]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>xsum</td>
#       <td>[i64, i64]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>memcpy.inline</td>
#       <td>[i8*, i8*, i64]</td>
#       <td>i8*</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>xmax</td>
#       <td>[i64, i64]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>rpl_vasprintf</td>
#       <td>[i8**, i8*, %"struct.std::__va_list"*]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>rpl_vfprintf</td>
#       <td>[%struct._IO_FILE*, i8*, %"struct.std::__va_list"*]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>rpl_vprintf</td>
#       <td>[i8*, %"struct.std::__va_list"*]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>usage</td>
#       <td>[i32]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>emit_ancillary_info</td>
#       <td>[i8*]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>main</td>
#       <td>[i32, i8**]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>usage</td>
#       <td>[i32]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>emit_mandatory_arg_note</td>
#       <td>[]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>emit_ancillary_info</td>
#       <td>[i8*]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>main</td>
#       <td>[i32, i8**]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>initialize_exit_failure</td>
#       <td>[i32]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>parse_duration</td>
#       <td>[i8*]</td>
#       <td>double</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>install_cleanup</td>
#       <td>[i32]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>install_sigchld</td>
#       <td>[]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>unblock_signal</td>
#       <td>[i32]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>settimeout</td>
#       <td>[double, i1]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>block_cleanup_and_chld</td>
#       <td>[i32, %struct.__sigset_t*]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>disable_core_dumps</td>
#       <td>[]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>apply_time_suffix</td>
#       <td>[double*, i8]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>cleanup</td>
#       <td>[i32]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>send_sig</td>
#       <td>[i32, i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>chld</td>
#       <td>[i32]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>usage</td>
#       <td>[i32]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>emit_mandatory_arg_note</td>
#       <td>[]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>emit_exec_status</td>
#       <td>[i8*]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>emit_ancillary_info</td>
#       <td>[i8*]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>main</td>
#       <td>[i32, i8**]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>initialize_exit_failure</td>
#       <td>[i32]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>perm_related_errno</td>
#       <td>[i32]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>ferror_unlocked</td>
#       <td>[%struct._IO_FILE*]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>operand2sig</td>
#       <td>[i8*, i8*]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>usage</td>
#       <td>[i32]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>emit_ancillary_info</td>
#       <td>[i8*]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>main</td>
#       <td>[i32, i8**]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>who</td>
#       <td>[i8*, i32]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>list_entries_who</td>
#       <td>[i64, %struct.gl_utmp*]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>scan_entries</td>
#       <td>[i64, %struct.gl_utmp*]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>print_heading</td>
#       <td>[]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>print_user</td>
#       <td>[%struct.gl_utmp*, i64]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>print_runlevel</td>
#       <td>[%struct.gl_utmp*]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>print_boottime</td>
#       <td>[%struct.gl_utmp*]</td>
#       <td>void</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>print_clockchange</td>
#       <td>[%struct.gl_utmp*]</td>
#       <

# %%
# %%db_query
# SELECT
#     argument_types,
#     COUNT(*) AS count
# FROM CoreUtilsArgumentTypes
# GROUP BY 1
# ORDER BY count DESC
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>argument_types</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>i8*</td>
#       <td>2168</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>i32</td>
#       <td>1337</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>i64</td>
#       <td>1097</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>None</td>
#       <td>329</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>i8**</td>
#       <td>281</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>%struct._IO_FILE*</td>
#       <td>261</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>i8</td>
#       <td>242</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>i1</td>
#       <td>204</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>i64*</td>
#       <td>174</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>%struct.stat*</td>
#       <td>130</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>i32*</td>
#       <td>86</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>%struct.fileinfo*</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>%struct.cp_options*</td>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>%struct.line*</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>%struct.hash_table*</td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>%struct.FTS*</td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>[2 x i64]</td>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>%struct._ftsent*</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>%struct.tm*</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>%struct.Spec_list*</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>%struct.blake2b_state__*</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>%struct.timespec*</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>fp128</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>%struct.gl_utmp*</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>i32 (i8*, i8*)*</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>%struct.tm_zone*</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>%struct.base_decode_context*</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>%struct.parser_control*</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>%struct.randint_source*</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>%struct.File_spec*</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>%struct.__mbstate_t*</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>%struct.termios*</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>%struct.quoting_options*</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>%struct.savewd*</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>%struct.obstack*</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>%struct.__mpz_struct*</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>%struct.scratch_buffer*</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>%"struct.std::__va_list"*</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>%struct.keyfield*</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>%struct.linebuffer*</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>%struct.COLUMN*</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>%struct.merge_node*</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>%struct.sha256_ctx*</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>%struct.sha512_ctx*</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>%struct.exclude*</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>double</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>%struct.randread_source*</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>%struct.item*</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>%struct._IO_FILE**</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>%struct.merge_node_queue*</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>%struct.mp_factors*</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>%struct.factors*</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>%struct.rm_options*</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>%struct.E_string*</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>%struct.valinfo*</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>fp128*</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>%struct.base64_decode_context*</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>%struct.base32_decode_context*</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>%struct.di_set*</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>%struct.sm3_ctx*</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>%struct.control*</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>%struct.Word*</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>i1 (i64)*</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>i16</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>%struct.I_ring*</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>%struct.sortfile*</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>%struct.sha1_ctx*</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>%struct.dynarray_header*</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>%struct.utmp_alloc*</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>%struct.md5_ctx*</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>%struct.duinfo*</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>%struct.field_values_t*</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>%struct.buffer_record*</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>double*</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>74</th>
#       <td>%struct.Chown_option*</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>75</th>
#       <td>%struct.Options*</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>76</th>
#       <td>%struct.cd_buf*</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>77</th>
#       <td>%struct.seq*</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td>%struct.__dirstream*</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>79</th>
#       <td>%struct.file_name*</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>80</th>
#       <td>%struct.Tokens*</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>81</th>
#       <td>%struct.splitbuf*</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>82</th>
#       <td>%struct.operand*</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>83</th>
#       <td>void (i8*)*</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>84</th>
#       <td>i32**</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>%struct.dir_list*</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>86</th>
#       <td>%struct.exclude_segment*</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>87</th>
#       <td>%struct.tm* (i64*, %struct.tm*)*</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>88</th>
#       <td>%struct.linebuffer**</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>89</th>
#       <td>%struct.argv_iterator*</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>90</th>
#       <td>%struct.

# %%
# %%db_query
# WITH
#     DistinctFunctions AS (
#         SELECT DISTINCT
#             function_name,
#             argument_types,
#             return_type
#         FROM CoreUtilsFunctions
#     )
# SELECT
#     return_type,
#     COUNT(*) AS num_instances
# FROM DistinctFunctions
# GROUP BY 1
# ORDER BY num_instances DESC
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>return_type</th>
#       <th>num_instances</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>void</td>
#       <td>680</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>i32</td>
#       <td>523</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>i1</td>
#       <td>422</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>i8*</td>
#       <td>230</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>i64</td>
#       <td>215</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>[2 x i64]</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>%struct.valinfo*</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>fp128</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>i32*</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>%struct._IO_FILE*</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>double</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>i8</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>%struct._ftsent*</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>i16</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>%struct.tempnode*</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>%struct.hash_table*</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>%struct.tm*</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>%struct.merge_node*</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>%struct.mode_change*</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>%struct.randread_source*</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>%struct.line*</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>%struct.randint_source*</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>%struct.FTS*</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>%struct.mount_entry*</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>%struct.stat*</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>%struct.control*</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>%struct.table*</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>%struct.cstring*</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>%struct.linebuffer*</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>%struct.item*</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>%struct.argv_iterator*</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>%struct.tm_zone*</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>i8**</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>%struct.__dirstream*</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>%struct.hash_entry*</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>%struct.buffer_record*</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>%struct.keyfield*</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>%struct.__locale_struct*</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>%struct.selabel_handle*</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>%struct.dirent*</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>%struct.quoting_options*</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>%struct.dev_ino*</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>%struct.bin_str*</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>%struct.ino_map*</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>%struct.devlist*</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>i64*</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>%struct.exclude*</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>%struct.file_name*</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>%struct.fstatus*</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>%struct.di_set*</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>%struct.heap*</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>void (i32)*</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>

# %%
# %%db_query
# WITH
#     DistinctFunctions AS (
#         SELECT DISTINCT
#             function_name,
#             argument_types,
#             return_type
#         FROM CoreUtilsFunctions
#     )
# SELECT
#     return_type,
#     ARRAY_SORT(argument_types) AS argument_types,
#     COUNT(*) AS num_instances
# FROM DistinctFunctions
# GROUP BY 1, 2
# ORDER BY num_instances DESC
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>return_type</th>
#       <th>argument_types</th>
#       <th>num_instances</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>void</td>
#       <td>[]</td>
#       <td>114</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>i32</td>
#       <td>[i8*, i8*]</td>
#       <td>95</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>void</td>
#       <td>[i8*]</td>
#       <td>53</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>i1</td>
#       <td>[i32]</td>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>i32</td>
#       <td>[i32]</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>i1</td>
#       <td>[i8*]</td>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>i64</td>
#       <td>[i64, i8*]</td>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>i8*</td>
#       <td>[i8*]</td>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>i1</td>
#       <td>[]</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>i1</td>
#       <td>[i8*, i8*]</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>void</td>
#       <td>[i32]</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>i1</td>
#       <td>[i64]</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>i64</td>
#       <td>[i8*]</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>i32</td>
#       <td>[]</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>i8*</td>
#       <td>[i64, i8*]</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>void</td>
#       <td>[i32, i8*]</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>void</td>
#       <td>[i32, i32, i64, i64, i8*, i8*]</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>i8*</td>
#       <td>[i32]</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>i8*</td>
#       <td>[i32, i8*]</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>i32</td>
#       <td>[i8*]</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>i8*</td>
#       <td>[i64, i8*, i8*]</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>void</td>
#       <td>[i64, i8*]</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>i32</td>
#       <td>[i32, i32]</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>i32</td>
#       <td>[%struct._IO_FILE*, i64*, i8*]</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>i64</td>
#       <td>[i64]</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>i1</td>
#       <td>[i8]</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>i32</td>
#       <td>[i32, i8*]</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>i8*</td>
#       <td>[i64]</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>i32</td>
#       <td>[i64, i64, i8*, i8*]</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>i32</td>
#       <td>[%struct.fileinfo*, %struct.fileinfo*, i32 (i8*, i8*)*]</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>void</td>
#       <td>[i64, i64]</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>i64</td>
#       <td>[i64, i64]</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>void</td>
#       <td>[i64, i64, i8*, i8*]</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>i8*</td>
#       <td>[i64, i64]</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>void</td>
#       <td>[i8*, i8*]</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>void</td>
#       <td>[%struct.base_decode_context*]</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>i32</td>
#       <td>[%struct._IO_FILE*, i8*]</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>i32</td>
#       <td>[%struct._IO_FILE*]</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>%struct.valinfo*</td>
#       <td>[i1]</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>i8*</td>
#       <td>[i8*, i8*]</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>void</td>
#       <td>[i1]</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>i64</td>
#       <td>[i32, i64, i8*]</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>i8*</td>
#       <td>[]</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>i64</td>
#       <td>[]</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>i1</td>
#       <td>[%struct.base_decode_context*, i64, i64*, i8*, i8*]</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>i1</td>
#       <td>[i64, i8*]</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>void</td>
#       <td>[%struct.gl_utmp*]</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>void</td>
#       <td>[i8]</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>i64</td>
#       <td>[i32, i64]</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>i32</td>
#       <td>[%struct.stat*, i8*]</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>void</td>
#       <td>[i64]</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>i1</td>
#       <td>[%struct.File_spec*, i64]</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>i32</td>
#       <td>[i64]</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>i32</td>
#       <td>[i32, i8**]</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>void</td>
#       <td>[%struct.cp_options*]</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>i32</td>
#       <td>[i32, i32, i32, i8*]</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>i8*</td>
#       <td>[i64, i64, i8*]</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>i1</td>
#       <td>[i32, i8*]</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>i32</td>
#       <td>[i32, i32, i8*]</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>i32</td>
#       <td>[i8*, i8**]</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>i8*</td>
#       <td>[i32, i64, i8*]</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>i8*</td>
#       <td>[%struct.hash_table*, i8*]</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>%struct._IO_FILE*</td>
#       <td>[i8*, i8*]</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>void</td>
#       <td>[%struct.COLUMN*]</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>i32</td>
#       <td>[%struct._IO_FILE*, i32]</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>i32</td>
#       <td>[i32, i64, i8*]</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>void</td>
#       <td>[i1, i8*]</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>void</td>
#       <td>[%struct._IO_FILE*]</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>void</td>
#       <td>[%struct._IO_FILE*, i8*]</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>void</td>
#       <td>[i64, i8*, i8*]</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>i1</td>
#       <td>[i32, i64, i64*, i8*]</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>i32</td>
#       <td>[%struct.timespec*]</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>i64</td>
#       <td>[%struct.stat*]</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>void</td>
#       <td>[%struct.line*]</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>74</th>
#       <td>i64</td>
#       <td>[fp128]</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>75</th>
#       <td>[2 x i64]</td>
#       <td>[%struct

# %%
# %%db_query
# WITH
#     DistinctFunctions AS (
#         SELECT DISTINCT
#             function_name,
#             argument_types,
#             return_type
#         FROM CoreUtilsFunctions
#     )
# SELECT
#     CAST(COUNT_IF(
#         LEN(argument_types) > 0
#         AND LIST_HAS_ALL(['i1', 'i8', 'i16', 'i32', 'i64'], argument_types)
#         AND return_type IN ('i1', 'i8', 'i16', 'i32', 'i64')
#     ) AS UINT64) AS num_primitive_functions,
#     COUNT(*) AS num_functions,
# FROM DistinctFunctions
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>num_primitive_functions</th>
#       <th>num_functions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>224</td>
#       <td>2206</td>
#     </tr>
#   </tbody>
# </table>

# %%
# %%db_query
# WITH
#     DistinctFunctions AS (
#         SELECT DISTINCT
#             function_name,
#             argument_types,
#             return_type
#         FROM CoreUtilsFunctions
#     )
# SELECT *
# FROM DistinctFunctions
# WHERE
#     LEN(argument_types) > 0
#     AND LIST_HAS_ALL(['i1', 'i8', 'i16', 'i32', 'i64'], argument_types)
#     AND return_type IN ('i1', 'i8', 'i16', 'i32', 'i64')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>function_name</th>
#       <th>argument_types</th>
#       <th>return_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ydhms_diff</td>
#       <td>[i64, i64, i32, i32, i32, i32, i32, i32, i32, i32]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>posixtest</td>
#       <td>[i32]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>isubase64</td>
#       <td>[i8]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>isubase64url</td>
#       <td>[i8]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>base16_length</td>
#       <td>[i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>base2_length</td>
#       <td>[i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>isuz85</td>
#       <td>[i8]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>c_isalnum</td>
#       <td>[i32]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>write_zeros</td>
#       <td>[i32, i64]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>multiple_bits_set</td>
#       <td>[i32]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>unsigned_file_size</td>
#       <td>[i64]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>mcel_isbasic</td>
#       <td>[i8]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>same_para</td>
#       <td>[i32]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>errnoize</td>
#       <td>[i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>errno_may_be_non_empty</td>
#       <td>[i32]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>ignorable_sync_errno</td>
#       <td>[i32]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>binvert</td>
#       <td>[i64]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>c32isxdigit</td>
#       <td>[i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>__bswap_64</td>
#       <td>[i64]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>xtime_nonnegative_sec</td>
#       <td>[i64]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>is_prime</td>
#       <td>[i64]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>time_overflow</td>
#       <td>[i64]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>floor_lg</td>
#       <td>[i64]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>uc_is_blank</td>
#       <td>[i32]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>uc_is_punct</td>
#       <td>[i32]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>isdst_differ</td>
#       <td>[i32, i32]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>send_sig</td>
#       <td>[i32, i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>known_value</td>
#       <td>[i64]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>set_binary_mode</td>
#       <td>[i32, i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>base64_required_padding</td>
#       <td>[i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>isubase2</td>
#       <td>[i8]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>is_range_start_index</td>
#       <td>[i64]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>iftruncate</td>
#       <td>[i32, i64]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>iclose</td>
#       <td>[i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>gnu_dev_major</td>
#       <td>[i64]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>gnu_dev_minor</td>
#       <td>[i64]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>print_type_indicator</td>
#       <td>[i1, i32, i32]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>calculate_columns</td>
#       <td>[i1]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>mcel_ch</td>
#       <td>[i32, i64]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>mcel_err</td>
#       <td>[i8]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>eq_tab</td>
#       <td>[i64]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>ignorable</td>
#       <td>[i32]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>iswnbspace</td>
#       <td>[i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>gid_unset</td>
#       <td>[i32]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>isbase32</td>
#       <td>[i8]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>rotl64</td>
#       <td>[i64, i32]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>rotr_sz</td>
#       <td>[i64, i32]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>c32isalnum</td>
#       <td>[i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>dup_cloexec</td>
#       <td>[i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>count_leading_zeros</td>
#       <td>[i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>count_leading_zeros_l</td>
#       <td>[i64]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>is_zero_or_power_of_two</td>
#       <td>[i64]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>ftypelet</td>
#       <td>[i32]</td>
#       <td>i8</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>xtime_nsec</td>
#       <td>[i64]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>hard_locale</td>
#       <td>[i32]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>errno_fail</td>
#       <td>[i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>uc_is_graph</td>
#       <td>[i32]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>uc_is_space</td>
#       <td>[i32]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>uc_is_xdigit</td>
#       <td>[i32]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>dup_safer</td>
#       <td>[i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>shr</td>
#       <td>[i64, i32]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>c_isprint</td>
#       <td>[i32]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>putchar_unlocked</td>
#       <td>[i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>c_tolower</td>
#       <td>[i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>__gl_setmode</td>
#       <td>[i32, i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>base32_length_wrapper</td>
#       <td>[i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>no_required_padding</td>
#       <td>[i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>count_leading_zeros_ll</td>
#       <td>[i64]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>errno_unsupported</td>
#       <td>[i32]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>cache_round</td>
#       <td>[i32, i64]</td>
#       <td>i64</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>format_user_width</td>
#       <td>[i32]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>off_cmp</td>
#       <td>[i64, i64]</td>
#       <td>i32</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>set_extend_size</td>
#       <td>[i64]</td>
#       <td>i1</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>print_gr
